# %%
import pandas as pd
import numpy as np
from functions import *
import matplotlib.pyplot as plt

#d = r'C:/Users/fabrizio/Documents/R_data/PROJECTS/MASTER/DATA/KKA Burgenland NEU.xlsx'

#data, trial = reader(d, 'Tabelle1', header=1, test=False)

# %%
data
# Out:
#     Unnamed: 0  ID Nr.  Ausbaugröße  Bewilligungsjahr  \
# 0            1     151           10              1997
# 1            2     158          170              1998
# 2            3     169            6              2006
# 3            4     170          480              2006
# 4            5     171            5              2009
# 5            6     177            6              2013
# 6            7     114            7              1997
# 7            8     129            5              1997
# 8            9     136            4               198
# 9           10     148            5              2000
# 10          11     149            6              2000
# 11          12     152            5              2000
# 12          13     161            6              2004
# 13          14     162            6              2000
# 14          15     167            5              2002
# 15          16     172            6              2010
# 16          17     173            8              2009
# 17          18     174            4              2013
# 18          19     175            4              2013
# 19          20     176           40              2007
# 20          21      88          100              1986
# 21          22     163           50              2002
# 22          23     159           10              2000
#
#                                           Type                     Einleitung
# 0             Belebungsanlage mit Nachklärung   Regenwasserkanal der Gemeinde
# 1             Belebungsanlage mit Nachklärung                       Vorfluter
# 2           Kompaktkläranlage- Belebungssystem                   Versickerung
# 3           Kompaktkläranlage- Belebungssystem                      Vorfluter
# 4           Kompaktkläranlage- Belebungssystem                      Vorfluter
# 5           Kompaktkläranlage- Belebungssystem                   Versickerung
# 6                           Pflanzenkläranlage                      Vorfluter
# 7                           Pflanzenkläranlage                   Versickerung
# 8                           Pflanzenkläranlage                   Versickerung
# 9                           Pflanzenkläranlage                   Versickerung
# 10                          Pflanzenkläranlage                   Versickerung
# 11                          Pflanzenkläranlage                   Versickerung
# 12                          Pflanzenkläranlage                   Versickerung
# 13                          Pflanzenkläranlage                   Versickerung
# 14                          Pflanzenkläranlage                   Versickerung
# 15                          Pflanzenkläranlage                   Versickerung
# 16                          Pflanzenkläranlage                   Versickerung
# 17                          Pflanzenkläranlage                   Versickerung
# 18                          Pflanzenkläranlage                   Versickerung
# 19  Pflanzenkläranlage (Beete, Schönungsteich)                   Versickerung
# 20                                         SBR                      Vorfluter
# 21                       SBR mit Pflanzenbeet                    Versickerung
# 22                         Tropfkörper mit NKB                   Versickerung

# %%
data=pd.read_excel('half-way/oebo.xlsx')
data.EW60.astype(int)
# Out:
# 0       50
# 1       50
# 2       50
# 3       50
# 4       50
#         ..
# 2517     3
# 2518     2
# 2519     2
# 2520     2
# 2521     2
# Name: EW60, Length: 2522, dtype: int32
